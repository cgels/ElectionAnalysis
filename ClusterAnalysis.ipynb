# %%
import pandas as pd 
from sklearn.cluster import AgglomerativeClustering
from sklearn.model_selection import cross_val_score

# %%
df=pd.read_csv("data/county_facts.csv")
df=df.dropna(subset=["state_abbreviation"])
#df=df.drop('Unnamed: 0',axis=1)
df=df.rename(index=str,columns={"PST045214": "Pop2014",
                            "PST040210": "Pop2010EST",
                            "PST120214": "Pop%Change",
                            "POP010210":"Pop2010",
                            "AGE135214": "Under5%",
                            "AGE295214": "Under18%",
                            "AGE775214": "Over65%",
                            "SEX255214": "Female%",
                            "RHI125214": "White%",
                            "RHI225214": "Black%",
                            "RHI325214": "NativeA%",
                            "RHI425214": "Asian%",
                            "RHI525214": "PIsland%",
                            "RHI625214": "TwoRace%",
                            "RHI725214": "Latino",
                            "RHI825214": "WhiteNLat%",
                            "POP715213": "SameHouse1yr%",
                            "POP645213": "ForeignBorn%",
                            "POP815213": "NonEnglish%",
                            "EDU635213": "HighSchoolGrad%",
                            "EDU685213": "Bachelor%",
                            "VET605213": "Veteran",
                            "LFE305213": "TravelTime",
                            "HSG010214": "HousingUnits",
                            "HSG445213": "OwnershipRate",
                            "HSG096213": "UnitsinMultiUnit%",
                            "HSG495213": "MedianValueHousing",
                             "HSD410213": "Households",
                            "INC910213": "PerCapitaIncome",
                            "INC110213": "MedianIncome",
                            "PVY020213": "%BelowPoverty",
                            "BZA010213": "PrivateNotFarmsEstablish",
                            "BZA110213": "PrivateNotFarmEmploy",
                            "BZA115213": "NotFarm%Change",
                            "NES010213": "NonEmployerEstablish",
                            "SBO315207": "Black-owned%",
                            "SBO115207": "Native-owned%",
                            "SBO215207": "Asian-owned%",
                            "SBO515207": "PIslnder-owned%",
                            "SBO415207": "Hispanic-owned%",
                            "SBO015207": "Woman-owned",
                            "MAN450207": "Manfact shipments 1k",
                            "WTN220207": "Merchant sales 1k",
                            "RTN130207": "Retail sales 1k",
                            "RTN131207": "Retail sales/capita",
                            "AFN120207": "Accomd/FoodServ sales 1k",
                            "BPS030214": "BuildingPermits",
                            "LND110210": "LandArea",
                            "POP060210": "Pop/SqMile",
                            "fips": "FIPS"})

# %%
x_vars=["PST040210",
"PST120214",
"POP010210",
"AGE135214",
"AGE295214",
"AGE775214",
"SEX255214",
"RHI125214",
"RHI225214",
"RHI325214",
"RHI425214",
"RHI525214",
"RHI625214",
"RHI725214",
"RHI825214",
"POP715213",
"POP645213",
"POP815213",
"EDU635213",
"EDU685213",
"VET605213",
"LFE305213",
"HSG010214",
"HSG445213",
"HSG096213",
"HSG495213",
"HSD410213",
"HSD310213",
"INC910213",
"INC110213",
"PVY020213",
"BZA010213",
"BZA110213",
"BZA115213",
"NES010213",
"SBO001207",
"SBO315207",
"SBO115207",
"SBO215207",
"SBO515207",
"SBO415207",
"SBO015207",
"MAN450207",
"WTN220207",
"RTN130207",
"RTN131207",
"AFN120207",
"BPS030214",
"LND110210",
"POP060210"
]

# %%
x_vars=["Pop2014","Pop2010EST","Pop%Change","Pop2010",
                    "Under5%","Under18%","Over65%","Female%",
                     "White%","Black%","NativeA%","Asian%",
                    "PIsland%","TwoRace%","Latino", "WhiteNLat%",
                     "SameHouse1yr%","ForeignBorn%","NonEnglish%","HighSchoolGrad%",
                    "Bachelor%","Veteran", "TravelTime","HousingUnits", 
                     "OwnershipRate","UnitsinMultiUnit%","MedianValueHousing",
                     "Households","PerCapitaIncome","MedianIncome","%BelowPoverty",
                     "PrivateNotFarmsEstablish","PrivateNotFarmEmploy","NotFarm%Change","NonEmployerEstablish",
                    "Black-owned%","Native-owned%","Asian-owned%","PIslnder-owned%",
                     "Hispanic-owned%","Woman-owned","Manfact shipments 1k",
                    "Merchant sales 1k","Retail sales 1k","Retail sales/capita",
                     "Accomd/FoodServ sales 1k","BuildingPermits","LandArea","Pop/SqMile"]

# %%
model=AgglomerativeClustering(n_clusters=8)

# %%
model.fit(df[x_vars])
# Out:
# AgglomerativeClustering(affinity='euclidean', compute_full_tree='auto',
#             connectivity=None, linkage='ward',
#             memory=Memory(cachedir=None), n_clusters=8,
#             pooling_func=<function mean at 0x7f1438117ea0>)

# %%
model.fit_predict(df[x_vars])
# Out:
# array([4, 4, 4, ..., 4, 4, 4])

# %%
df['Current_Cluster']=model.fit_predict(df[x_vars])

# %%
df.groupby('Current_Cluster').count()
# Out:
#                  FIPS  area_name  state_abbreviation  Pop2014  Pop2010EST  \
# Current_Cluster
# 0                  77         77                  77       77          77
# 1                   2          2                   2        2           2
# 2                 296        296                 296      296         296
# 3                   4          4                   4        4           4
# 4                2733       2733                2733     2733        2733
# 5                  22         22                  22       22          22
# 6                   7          7                   7        7           7
# 7                   2          2                   2        2           2
#
#                  Pop%Change  Pop2010  Under5%  Under18%  Over65%     ...      \
# Current_Cluster                                                      ...
# 0                        77       77       77        77       77     ...
# 1                         2        2        2         2        2     ...
# 2                       296      296      296       296      296     ...
# 3                         4        4        4         4        4     ...
# 4                      2733     2733     2733      2733     2733     ...
# 5                        22       22       22        22       22     ...
# 6                         7        7        7         7        7     ...
# 7                         2        2        2         2        2     ...
#
#                  Hispanic-owned%  Woman-owned  Manfact shipments 1k  \
# Current_Cluster
# 0                             77           77                    77
# 1                              2            2                     2
# 2                            296          296                   296
# 3                              4            4                     4
# 4                           2733         2733                  2733
# 5                             22           22                    22
# 6                              7            7                     7
# 7                              2            2                     2
#
#                  Merchant sales 1k  Retail sales 1k  Retail sales/capita  \
# Current_Cluster
# 0                               77               77                   77
# 1                                2                2                    2
# 2                              296              296                  296
# 3                                4                4                    4
# 4                             2733             2733                 2733
# 5                               22               22                   22
# 6                                7                7                    7
# 7                                2                2                    2
#
#                  Accomd/FoodServ sales 1k  BuildingPermits  LandArea  \
# Current_Cluster
# 0                                      77               77        77
# 1                                       2                2         2
# 2                                     296              296       296
# 3                                       4                4         4
# 4                                    2733             2733      2733
# 5                                      22               22        22
# 6                                       7                7         7
# 7                                       2                2         2
#
#                  Pop/SqMile
# Current_Cluster
# 0                        77
# 1                         2
# 2                       296
# 3                         4
# 4                      2733
# 5                        22
# 6                         7
# 7                         2
#
# [8 rows x 54 columns]

# %%
#Clusters don't provide anything interesting
model=AgglomerativeClustering(n_clusters=6)
df['Current_Cluster']=model.fit_predict(df[x_vars])

# %%
df.groupby("Current_Cluster").count()
# Out:
#                  FIPS  area_name  state_abbreviation  Pop2014  Pop2010EST  \
# Current_Cluster
# 0                  13         13                  13       13          13
# 1                  77         77                  77       77          77
# 2                 296        296                 296      296         296
# 3                   2          2                   2        2           2
# 4                2733       2733                2733     2733        2733
# 5                  22         22                  22       22          22
#
#                  Pop%Change  Pop2010  Under5%  Under18%  Over65%     ...      \
# Current_Cluster                                                      ...
# 0                        13       13       13        13       13     ...
# 1                        77       77       77        77       77     ...
# 2                       296      296      296       296      296     ...
# 3                         2        2        2         2        2     ...
# 4                      2733     2733     2733      2733     2733     ...
# 5                        22       22       22        22       22     ...
#
#                  Hispanic-owned%  Woman-owned  Manfact shipments 1k  \
# Current_Cluster
# 0                             13           13                    13
# 1                             77           77                    77
# 2                            296          296                   296
# 3                              2            2                     2
# 4                           2733         2733                  2733
# 5                             22           22                    22
#
#                  Merchant sales 1k  Retail sales 1k  Retail sales/capita  \
# Current_Cluster
# 0                               13               13                   13
# 1                               77               77                   77
# 2                              296              296                  296
# 3                                2                2                    2
# 4                             2733             2733                 2733
# 5                               22               22                   22
#
#                  Accomd/FoodServ sales 1k  BuildingPermits  LandArea  \
# Current_Cluster
# 0                                      13               13        13
# 1                                      77               77        77
# 2                                     296              296       296
# 3                                       2                2         2
# 4                                    2733             2733      2733
# 5                                      22               22        22
#
#                  Pop/SqMile
# Current_Cluster
# 0                        13
# 1                        77
# 2                       296
# 3                         2
# 4                      2733
# 5                        22
#
# [6 rows x 54 columns]

# %%
demographic_vars=["Female%",
                     "White%","Black%","NativeA%","Asian%",
                    "PIsland%","TwoRace%","Latino", "WhiteNLat%"]

# %%
model=AgglomerativeClustering(n_clusters=7)
df['Demographic_Cluster']=model.fit_predict(df[demographic_vars])

# %%
df.groupby("Demographic_Cluster").count()
# Out:
#                      FIPS  area_name  state_abbreviation  Pop2014  Pop2010EST  \
# Demographic_Cluster
# 0                     241        241                 241      241         241
# 1                     296        296                 296      296         296
# 2                     792        792                 792      792         792
# 3                     115        115                 115      115         115
# 4                      40         40                  40       40          40
# 5                    1369       1369                1369     1369        1369
# 6                     290        290                 290      290         290
#
#                      Pop%Change  Pop2010  Under5%  Under18%  Over65%  \
# Demographic_Cluster
# 0                           241      241      241       241      241
# 1                           296      296      296       296      296
# 2                           792      792      792       792      792
# 3                           115      115      115       115      115
# 4                            40       40       40        40       40
# 5                          1369     1369     1369      1369     1369
# 6                           290      290      290       290      290
#
#                           ...         Woman-owned  Manfact shipments 1k  \
# Demographic_Cluster       ...
# 0                         ...                 241                   241
# 1                         ...                 296                   296
# 2                         ...                 792                   792
# 3                         ...                 115                   115
# 4                         ...                  40                    40
# 5                         ...                1369                  1369
# 6                         ...                 290                   290
#
#                      Merchant sales 1k  Retail sales 1k  Retail sales/capita  \
# Demographic_Cluster
# 0                                  241              241                  241
# 1                                  296              296                  296
# 2                                  792              792                  792
# 3                                  115              115                  115
# 4                                   40               40                   40
# 5                                 1369             1369                 1369
# 6                                  290              290                  290
#
#                      Accomd/FoodServ sales 1k  BuildingPermits  LandArea  \
# Demographic_Cluster
# 0                                         241              241       241
# 1                                         296              296       296
# 2                                         792              792       792
# 3                                         115              115       115
# 4                                          40               40        40
# 5                                        1369             1369      1369
# 6                                         290              290       290
#
#                      Pop/SqMile  Current_Cluster
# Demographic_Cluster
# 0                           241              241
# 1                           296              296
# 2                           792              792
# 3                           115              115
# 4                            40               40
# 5                          1369             1369
# 6                           290              290
#
# [7 rows x 55 columns]

# %%
economic_vars=["PerCapitaIncome","MedianIncome","%BelowPoverty"]

# %%
model=AgglomerativeClustering(n_clusters=3)
df['Economic_Cluster']=model.fit_predict(df[economic_vars])

# %%
df.groupby("Current_Cluster").count()
# Out:
#                  FIPS  area_name  state_abbreviation  Pop2014  Pop2010EST  \
# Current_Cluster
# 0                  13         13                  13       13          13
# 1                  77         77                  77       77          77
# 2                 296        296                 296      296         296
# 3                   2          2                   2        2           2
# 4                2733       2733                2733     2733        2733
# 5                  22         22                  22       22          22
#
#                  Pop%Change  Pop2010  Under5%  Under18%  Over65%  \
# Current_Cluster
# 0                        13       13       13        13       13
# 1                        77       77       77        77       77
# 2                       296      296      296       296      296
# 3                         2        2        2         2        2
# 4                      2733     2733     2733      2733     2733
# 5                        22       22       22        22       22
#
#                        ...         Manfact shipments 1k  Merchant sales 1k  \
# Current_Cluster        ...
# 0                      ...                           13                 13
# 1                      ...                           77                 77
# 2                      ...                          296                296
# 3                      ...                            2                  2
# 4                      ...                         2733               2733
# 5                      ...                           22                 22
#
#                  Retail sales 1k  Retail sales/capita  \
# Current_Cluster
# 0                             13                   13
# 1                             77                   77
# 2                            296                  296
# 3                              2                    2
# 4                           2733                 2733
# 5                             22                   22
#
#                  Accomd/FoodServ sales 1k  BuildingPermits  LandArea  \
# Current_Cluster
# 0                                      13               13        13
# 1                                      77               77        77
# 2                                     296              296       296
# 3                                       2                2         2
# 4                                    2733             2733      2733
# 5                                      22               22        22
#
#                  Pop/SqMile  Demographic_Cluster  Economic_Cluster
# Current_Cluster
# 0                        13                   13                13
# 1                        77                   77                77
# 2                       296                  296               296
# 3                         2                    2                 2
# 4                      2733                 2733              2733
# 5                        22                   22                22
#
# [6 rows x 56 columns]

# %%
#df.ix[df['Current_Cluster']==7][x_vars]

# %%
df.groupby('Economic_Cluster').mean()[x_vars]
# Out:
#                         Pop2014     Pop2010EST  Pop%Change        Pop2010  \
# Economic_Cluster
# 0                 256375.926829  245047.114983    3.698955  245028.777003
# 1                  37904.549396   37736.795309   -1.057427   37738.013504
# 2                 101863.660069   98971.936317    0.712737   98968.704819
#
#                    Under5%   Under18%    Over65%    Female%     White%  \
# Economic_Cluster
# 0                 5.925784  23.251568  14.880314  49.990592  85.657491
# 1                 5.897512  22.371642  18.269225  49.835537  81.321180
# 2                 5.877539  22.390534  18.053012  49.938124  89.268675
#
#                      Black%     ...      Hispanic-owned%  Woman-owned  \
# Economic_Cluster                ...
# 0                  6.542509     ...             2.500348    23.397038
# 1                 13.186567     ...             1.713859    16.233049
# 2                  5.757143     ...             1.261446    17.340017
#
#                   Manfact shipments 1k  Merchant sales 1k  Retail sales 1k  \
# Economic_Cluster
# 0                         3.672827e+06       4.051161e+06     3.352494e+06
# 1                         5.093396e+05       1.752218e+05     3.786515e+05
# 2                         1.408937e+06       1.061726e+06     1.254048e+06
#
#                   Retail sales/capita  Accomd/FoodServ sales 1k  \
# Economic_Cluster
# 0                        12328.855401             526150.259582
# 1                         8778.579957              47542.970860
# 2                        10967.312392             204301.893287
#
#                   BuildingPermits     LandArea  Pop/SqMile
# Economic_Cluster
# 0                      998.426829  1386.157787  694.925261
# 1                       68.237385  1033.446546  116.637456
# 2                      324.110155  1103.436446  216.914286
#
# [3 rows x 49 columns]

# %%
owned_vars=["Black-owned%","Native-owned%","Asian-owned%","PIslnder-owned%",
                     "Hispanic-owned%","Woman-owned"]

# %%
model=AgglomerativeClustering(n_clusters=7)
df['Owned_Cluster']=model.fit_predict(df[owned_vars])

# %%
df.groupby("Current_Cluster").mean()[x_vars]
# Out:
#                       Pop2014    Pop2010EST  Pop%Change       Pop2010  \
# Current_Cluster
# 0                2.471086e+06  2.364198e+06    4.523077  2.364018e+06
# 1                7.651135e+05  7.366467e+05    3.718182  7.366421e+05
# 2                2.859993e+05  2.757933e+05    3.058784  2.757692e+05
# 3                7.279038e+06  6.955838e+06    5.750000  6.955532e+06
# 4                3.627781e+04  3.574508e+04    0.035419  3.574436e+04
# 5                1.339004e+06  1.275633e+06    4.763636  1.275626e+06
#
#                   Under5%   Under18%    Over65%    Female%     White%  \
# Current_Cluster
# 0                6.307692  22.753846  13.123077  50.992308  70.869231
# 1                6.302597  23.154545  13.619481  51.264935  72.301299
# 2                6.136824  23.211486  14.770608  50.872297  81.302365
# 3                7.050000  24.950000  10.700000  50.450000  70.900000
# 4                5.851189  22.438529  18.048774  49.743286  86.008562
# 5                6.350000  23.518182  12.890909  51.068182  70.877273
#
#                     Black%     ...       Hispanic-owned%  Woman-owned  \
# Current_Cluster                ...
# 0                14.015385     ...             13.223077    29.738462
# 1                17.402597     ...              5.753247    29.063636
# 2                12.083784     ...              3.781419    26.819932
# 3                14.350000     ...             22.300000    29.700000
# 4                 8.594694     ...              1.211453    16.522027
# 5                17.350000     ...             10.122727    29.163636
#
#                  Manfact shipments 1k  Merchant sales 1k  Retail sales 1k  \
# Current_Cluster
# 0                        3.578565e+07       6.089743e+07     3.442630e+07
# 1                        1.324451e+07       1.118703e+07     9.534049e+06
# 2                        4.589137e+06       2.615399e+06     3.601223e+06
# 3                        1.613094e+08       2.019573e+08     8.550545e+07
# 4                        3.522684e+05       1.341174e+05     3.928813e+05
# 5                        1.514703e+07       2.763388e+07     1.917806e+07
#
#                  Retail sales/capita  Accomd/FoodServ sales 1k  \
# Current_Cluster
# 0                       15520.230769              6.800680e+06
# 1                       13634.051948              1.378012e+06
# 2                       13598.493243              5.312008e+05
# 3                       12756.000000              1.405644e+07
# 4                        9702.544823              5.181977e+04
# 5                       16042.545455              3.855206e+06
#
#                  BuildingPermits     LandArea   Pop/SqMile
# Current_Cluster
# 0                    8454.230769  1821.058462  7436.092308
# 1                    2527.805195   593.113636  2680.985714
# 2                    1067.121622   859.275135   703.847297
# 3                   28859.500000  2880.680000  2411.000000
# 4                     100.498719  1153.955104    97.021515
# 5                    4223.954545  2213.518182  1528.395455
#
# [6 rows x 49 columns]

# %%
age_vars=["Under5%","Under18%","Over65%"]
model=AgglomerativeClustering(n_clusters=5)
df['Age_Cluster']=model.fit_predict(df[age_vars])

# %%
df.groupby("Age_Cluster").count()
# Out:
#              FIPS  area_name  state_abbreviation  Pop2014  Pop2010EST  \
# Age_Cluster
# 0             558        558                 558      558         558
# 1             385        385                 385      385         385
# 2            1310       1310                1310     1310        1310
# 3             732        732                 732      732         732
# 4             158        158                 158      158         158
#
#              Pop%Change  Pop2010  Under5%  Under18%  Over65%      ...        \
# Age_Cluster                                                       ...
# 0                   558      558      558       558      558      ...
# 1                   385      385      385       385      385      ...
# 2                  1310     1310     1310      1310     1310      ...
# 3                   732      732      732       732      732      ...
# 4                   158      158      158       158      158      ...
#
#              Retail sales 1k  Retail sales/capita  Accomd/FoodServ sales 1k  \
# Age_Cluster
# 0                        558                  558                       558
# 1                        385                  385                       385
# 2                       1310                 1310                      1310
# 3                        732                  732                       732
# 4                        158                  158                       158
#
#              BuildingPermits  LandArea  Pop/SqMile  Current_Cluster  \
# Age_Cluster
# 0                        558       558         558              558
# 1                        385       385         385              385
# 2                       1310      1310        1310             1310
# 3                        732       732         732              732
# 4                        158       158         158              158
#
#              Demographic_Cluster  Economic_Cluster  Owned_Cluster
# Age_Cluster
# 0                            558               558            558
# 1                            385               385            385
# 2                           1310              1310           1310
# 3                            732               732            732
# 4                            158               158            158
#
# [5 rows x 58 columns]

# %%
df.groupby('Current_Cluster').mean()[x_vars]
# Out:
#                       Pop2014    Pop2010EST  Pop%Change       Pop2010  \
# Current_Cluster
# 0                2.471086e+06  2.364198e+06    4.523077  2.364018e+06
# 1                7.651135e+05  7.366467e+05    3.718182  7.366421e+05
# 2                2.859993e+05  2.757933e+05    3.058784  2.757692e+05
# 3                7.279038e+06  6.955838e+06    5.750000  6.955532e+06
# 4                3.627781e+04  3.574508e+04    0.035419  3.574436e+04
# 5                1.339004e+06  1.275633e+06    4.763636  1.275626e+06
#
#                   Under5%   Under18%    Over65%    Female%     White%  \
# Current_Cluster
# 0                6.307692  22.753846  13.123077  50.992308  70.869231
# 1                6.302597  23.154545  13.619481  51.264935  72.301299
# 2                6.136824  23.211486  14.770608  50.872297  81.302365
# 3                7.050000  24.950000  10.700000  50.450000  70.900000
# 4                5.851189  22.438529  18.048774  49.743286  86.008562
# 5                6.350000  23.518182  12.890909  51.068182  70.877273
#
#                     Black%     ...       Hispanic-owned%  Woman-owned  \
# Current_Cluster                ...
# 0                14.015385     ...             13.223077    29.738462
# 1                17.402597     ...              5.753247    29.063636
# 2                12.083784     ...              3.781419    26.819932
# 3                14.350000     ...             22.300000    29.700000
# 4                 8.594694     ...              1.211453    16.522027
# 5                17.350000     ...             10.122727    29.163636
#
#                  Manfact shipments 1k  Merchant sales 1k  Retail sales 1k  \
# Current_Cluster
# 0                        3.578565e+07       6.089743e+07     3.442630e+07
# 1                        1.324451e+07       1.118703e+07     9.534049e+06
# 2                        4.589137e+06       2.615399e+06     3.601223e+06
# 3                        1.613094e+08       2.019573e+08     8.550545e+07
# 4                        3.522684e+05       1.341174e+05     3.928813e+05
# 5                        1.514703e+07       2.763388e+07     1.917806e+07
#
#                  Retail sales/capita  Accomd/FoodServ sales 1k  \
# Current_Cluster
# 0                       15520.230769              6.800680e+06
# 1                       13634.051948              1.378012e+06
# 2                       13598.493243              5.312008e+05
# 3                       12756.000000              1.405644e+07
# 4                        9702.544823              5.181977e+04
# 5                       16042.545455              3.855206e+06
#
#                  BuildingPermits     LandArea   Pop/SqMile
# Current_Cluster
# 0                    8454.230769  1821.058462  7436.092308
# 1                    2527.805195   593.113636  2680.985714
# 2                    1067.121622   859.275135   703.847297
# 3                   28859.500000  2880.680000  2411.000000
# 4                     100.498719  1153.955104    97.021515
# 5                    4223.954545  2213.518182  1528.395455
#
# [6 rows x 49 columns]

# %%
df2=pd.read_csv("data/US_County_Level_Presidential_Results_12-16.csv")
df2=df2.drop('Unnamed: 0',axis=1)
df2=df2[df2['state_abbr']!="AK"]

# %%
merged=pd.merge(df,df2, on='FIPS')
merged['change']=merged['per_point_diff_2016']-merged['per_point_diff_2012']

# %%
merged.groupby('Owned_Cluster').mean()[["per_point_diff_2016","per_point_diff_2012",'change']]
# Out:
#                per_point_diff_2016  per_point_diff_2012    change
# Owned_Cluster
# 0                        -0.236131            -0.152195 -0.083936
# 1                        -0.456880            -0.324080 -0.132800
# 2                         0.060045             0.046205  0.013839
# 3                         0.121143             0.174149 -0.053006
# 4                        -0.376572            -0.252221 -0.124352
# 5                         0.465385             0.605231 -0.139846
# 6                         0.270833             0.307466 -0.036632

# %%
df.groupby("Age_Cluster").mean()[age_vars]
# Out:
#               Under5%   Under18%    Over65%
# Age_Cluster
# 0            7.459140  27.150896  12.293369
# 1            4.718961  18.987792  25.696364
# 2            5.844122  22.571374  16.584351
# 3            5.559973  21.730738  20.225000
# 4            5.216456  18.387342  12.282911
